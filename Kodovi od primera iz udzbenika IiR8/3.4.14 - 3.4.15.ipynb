# %%
Struja = [2, 4, 6, 8, 10]

# %%
PromenaNapona = Struja*2

# %%
PromenaNapona

# %%
import pandas as pd

# %%
SerijaStruja = pd.Series(Struja)

# %%
PromenaNapona = SerijaStruja*2

# %%
PromenaNapona
