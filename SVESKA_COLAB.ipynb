# %% [markdown]
# <a href="https://colab.research.google.com/github/vulkanznanje/fajlovi/blob/master/SVESKA_COLAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
OVO JE SVESKA NAPRAVLJENA U GOOGLE COLAB-U

# %% [markdown]
# **OVO JE SVESKA NAPRAVLJENA U GOOGLE COLAB-U**
