# %% [markdown]
# ### Lekcija 3.5

# %% [markdown]
# Prvi zadatak
# 1. Nа osnovu podataka iz tabele na slici napravi ugnježđenu listu. Nazovi je Struja.
# 2. Od liste napravi tabelu (Data Frame) pod nazivom StrujaOsigurača.
# 3. Prikaži tabelu.
# 4. Umesto indeksa, kolonama dodeli odgovarajuće nazive pa ponovo prikaži tabelu.
# 5. Tabelu sačuvaj u svoj folder kao *CSV* fajl. U fajlu ne treba da se nalayi indeksna kolona ali treba da se koriste slova srpske latinice.
# <table><tr>
# <td> <img src=attachment:Tabela_osigurac.png alt="Drawing" style="width: 250px;"/> </td>
# <td> <img src=attachment:Osigurac%20manja%20slika.jpg alt="Drawing" style="width: 180px;"/> </td>
# </tr></table>

# %% [markdown]
# Drugi zadatak
# 1. Nа osnovu podataka iz tabele na slici napravi ugnježđenu listu. Nazovi je Nemetali.
# 2. Od liste napravi tabelu (Data Frame) pod nazivom TabelaNemetali.
# 3. Prikaži tabelu.
# 4. Umesto indeksa, kolonama dodeli odgovarajuće nazive pa ponovo prikaži tabelu.
# 5. Tabelu sačuvaj u svoj folder kao *txt* fajl. U fajlu ne treba da se nalazi indeksna kolona ali treba da se koriste slova srpske latinice.
# <table><tr>
# <td> <img src=attachment:Hemija%20-%20NeMetali.png alt="Drawing" style="width: 370px;"/> </td>
# <td> <img src=attachment:stock-photo-piece-of-sulphur-placed-an-periodic-table-of-chemical-elements-1614893584.jpg alt="Drawing" style="width: 350px;"/> </td>
# </tr></table>

# %% [markdown]
# Treći zadatak
# 1. Nа osnovu podataka iz tabele na slici napravi ugnježđenu listu. Nazovi je Okruzi.
# 2. Od liste napravi tabelu (Data Frame) pod nazivom UžaSrbija.
# 3. Prikaži tabelu.
# 4. Umesto indeksa, kolonama dodeli odgovarajuće nazive pa ponovo prikaži tabelu.
# 5. Tabelu sačuvaj u svoj folder kao *Excel* fajl. U fajlu ne treba da se nalayi indeksna kolona ali treba da se koriste slova srpske latinice.
# <table><tr>
# <td> <img src=attachment:Tabela_okruzi.png alt="Drawing" style="width: 320px;"/> </td>
# <td> <img src=attachment:Srbija%20stanovnici%20manja%20slika.jpg alt="Drawing" style="width: 320px;"/> </td>
# </tr></table>

# %% [markdown]
# Četvrti zadatak
# 1. Na *URL* adresi https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv se nalazi javno dostupan spisak svih država na svetu. Uvezi tabelu u svesku, sačuvaj je u promenljivu DržaveSveta i prikaži njen sadržaj.
