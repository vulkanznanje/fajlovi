# %% [markdown]
# ### Lekcija 3.5

# %% [markdown]
# Prvi zadatak
# 1. Nа osnovu podataka iz tabele na slici napravi ugnježđenu listu. Nazovi je Struja.
# 2. Od liste napravi tabelu (Data Frame) pod nazivom StrujaOsigurača.
# 3. Prikaži tabelu.
# 4. Umesto indeksa, kolonama dodeli odgovarajuće nazive pa ponovo prikaži tabelu.
# 5. Tabelu sačuvaj u svoj folder kao *CSV* fajl. U fajlu ne treba da se nalayi indeksna kolona ali treba da se koriste slova srpske latinice.
# <table><tr>
# <td> <img src=attachment:Tehnika%20-%20Struja%20osiguraca.png alt="Drawing" style="width: 250px;"/> </td>
# <td> <img src=attachment:Osigurac%20manja%20slika.jpg alt="Drawing" style="width: 120px;"/> </td>
# </tr></table>

# %% [markdown]
# Drugi zadatak
# 1. Nа osnovu podataka iz tabele na slici napravi ugnježđenu listu. Nazovi je Metali.
# 2. Od liste napravi tabelu (Data Frame) pod nazivom TabelaMetali.
# 3. Prikaži tabelu.
# 4. Umesto indeksa, kolonama dodeli odgovarajuće nazive pa ponovo prikaži tabelu.
# 5. Tabelu sačuvaj u svoj folder kao *txt* fajl. U fajlu ne treba da se nalayi indeksna kolona ali treba da se koriste slova srpske latinice.
# <table><tr>
# <td> <img src=attachment:Tabela_metali.png alt="Drawing" style="width: 320px;"/> </td>
# <td> <img src=stock-photo-piece-of-aluminum-on-periodic-table-of-elements-255801601.jpg alt="Drawing" style="width: 350px;"/> </td>
# </tr></table>

# %% [markdown]
# Treći zadatak
# 1. Nа osnovu podataka iz tabele na slici napravi ugnježđenu listu. Nazovi je Struja.
# 2. Od liste napravi tabelu (Data Frame) pod nazivom StrujaOsigurača.
# 3. Prikaži tabelu.
# 4. Umesto indeksa, kolonama dodeli odgovarajuće nazive pa ponovo prikaži tabelu.
# 5. Tabelu sačuvaj u svoj folder kao *Excel* fajl. U fajlu ne treba da se nalayi indeksna kolona ali treba da se koriste slova srpske latinice.
# <table><tr>
# <td> <img src=attachment:Tabela_okruzi.png alt="Drawing" style="width: 320px;"/> </td>
# <td> <img src=attachment:Srbija%20stanovnici%20manja%20slika.jpg alt="Drawing" style="width: 320px;"/> </td>
# </tr></table>
