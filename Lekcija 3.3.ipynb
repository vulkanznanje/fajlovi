# %% [markdown]
# ### Lekcija 3.3

# %% [markdown]
# Prvi zadatak
#
# Na slici je prikazano nekoliko ostrva. Tačkama A, B i C označene su luke, a linijama trase kojima plove brodovi od luke do luke.
# 1. Korišćenjem funkcija iz biblioteke **math** izračunaj najkraće rastojanje od luke A do luke B.
# ![%D0%BF%D0%B8%D1%82%D0%B0%D0%B3%D0%BE%D1%80%D0%B8%D0%BD%D0%B0%20%D1%82%D0%B5%D0%BE%D1%80%D0%B5%D0%BC%D0%B0.png](attachment:%D0%BF%D0%B8%D1%82%D0%B0%D0%B3%D0%BE%D1%80%D0%B8%D0%BD%D0%B0%20%D1%82%D0%B5%D0%BE%D1%80%D0%B5%D0%BC%D0%B0.png)

# %% [markdown]
# 2. Korišćenjem funkcije iz biblioteke **math** i operatora za stepenovanje izračunaj najkraće rastojanje od luke A do luke B.

# %% [markdown]
# Drugi zadatak
#
# Na slici je prikazan jednakokraki trapez čije su osnovice 7cm i 23cm, a krak dužine 17cm.
# 1. Korišćenjem funkcija iz biblioteke **math** njegovu površinu.
# <table><tr>
# <td> <img src=attachment:Trapez.png alt="Drawing" style="width: 250px;"/> </td>
# </tr></table>

# %% [markdown]
# Treći zadatak
#
# Na slici je prikazana pravilna trostrana prizma čija je osnovica 12cm, a visina prizme 10cm.
# 1. Korišćenjem funkcija iz biblioteke **math** izračunaj njenu površinu.
# <table><tr>
# <td> <img src=attachment:3prizma.png alt="Drawing" style="width: 150px;"/> </td>
# </tr></table>

# %% [markdown]
# Četvrti zadatak
#
# Na slici je prikazana pravilna četvorostrana piramida čija je osnovica a = 12cm, a visina piramide H = 10cm.
# 1. Korišćenjem funkcija iz biblioteke **math** izračunaj njenu površinu i zapreminu.
# <table><tr>
# <td> <img src=attachment:Pravilna%20cetvorostrana%20piramida.png alt="Drawing" style="width: 250px;"/> </td>
# </tr></table>
